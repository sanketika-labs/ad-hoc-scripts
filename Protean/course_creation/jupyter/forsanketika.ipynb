# %%
# !! pip3 install openpyxl
import pandas as pd

# %%
quiz = pd.read_csv('../csv/quiz.csv')

# %%
quiz.columns
# Out:
# Index(['COURSE_TITLE', 'COURSE_CODE', 'MODULES_TITLE', 'MODULE_CODE',
#        'url MODULE video', 'QUIZ_CODE ', 'Question_code', 'Question',
#        'option 1', 'answer', 'option 3', 'answer.1', 'option 4', 'answer.2',
#        'option5', 'answer.3', 'option6', 'answer.4', 'option7', 'answer.5',
#        'option8', 'answer.6', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27'],
#       dtype='object')

# %%
questions = quiz[['Question_code', 'Question',
       'option 1', 'answer', 'option 3', 'answer.1', 'option 4', 'answer.2',
       'option5', 'answer.3', 'option6', 'answer.4', 'option7', 'answer.5',
       'option8', 'answer.6']]

questions = questions.rename(columns={
    "Question_code":"code",
    "Question":"question_text",
    "option 1":"option_1",
    "answer":"option_1_is_correct",
    "option 3":"option_2",
    "answer.1":"option_2_is_correct",
    "option 4":"option_3",
    "answer.2":"option_3_is_correct",
    'option5':'option_4',
    'answer.3':'option_4_is_correct',
    'option6':'option_5',
    'answer.4':'option_5_is_correct',
    'option7':'option_6',
    'answer.5':'option_6_is_correct',
    'option8':'option_7',
    'answer.6':'option_7_is_correct'
})
questions.dropna(inplace=True,how='all')
questions['score'] = 1

# %%
questions
# Out:
#                   code                                      question_text  \
# 0    FMPS_MC003_01_Q01  من بين العبارات التالية، حدد تلك التي تبدو لك ...
# 1    FMPS_MC003_01_Q02   أجب بصحيح أو خطأ على العبارة الموالية:\nالترب...
# 2    FMPS_MC003_01_Q03   أجب بصحيح أو خطأ على العبارة الموالية:\nالترب...
# 3    FMPS_MC003_01_Q04   أجب بصحيح أو خطأ على العبارة الموالية:\nالغاي...
# 4    FMPS_MC003_01_Q05   أجب بصحيح أو خطأ على العبارة الموالية:\nالهدف...
# ..                 ...                                                ...
# 107   FMPS_MC004_12_Q4  من بين العبارات التالية، حدد تلك التي تبدو لك ...
# 108   FMPS_MC004_12_Q5   أجب بصحيح او  خطأ على العبارة الموالية: تساعد...
# 109   FMPS_MC004_12_Q6   أجب بصحيح او  خطأ على العبارة الموالية: لا تس...
# 110   FMPS_MC004_12_Q7   أجب بصحيح او  خطأ على العبارة الموالية:تساهم ...
# 111   FMPS_MC004_12_Q8   أجب بصحيح او  خطأ على العبارة الموالية: تلعب ...
#
#                                          option_1 option_1_is_correct  \
# 0    الأسرة هي أول متدخل في المحيط المجتمعي للطفل               true
# 1                                             خطأ              false
# 2                                           صحيح                true
# 3                                           صحيح                true
# 4                                           صحيح                true
# ..                                            ...                 ...
# 107                 تشجيع إنشاء تجارب تعليمية\n\n              true
# 108                                          صحيح              true
# 109                                           خطأ              false
# 110                                          صحيح              true
# 111                                          صحيح              true
#
#                                               option_2 option_2_is_correct  \
# 0    لا تؤثر الأسرة في شخصية الطفل ونموه الانفعالي ...              false
# 1                                                  NaN                 NaN
# 2                                                  NaN                 NaN
# 3                                                  NaN                 NaN
# 4                                                  NaN                 NaN
# ..                                                 ...                 ...
# 107                                 تشجع على الإتكالية              false
# 108                                                NaN                 NaN
# 109                                                NaN                 NaN
# 110                                                NaN                 NaN
# 111                                                NaN                 NaN
#
#                                               option_3 option_3_is_correct  \
# 0    الأسرة تلعب دورا مهما في تأسيس شخصية الطفل بشك...               true
# 1                                                  NaN                 NaN
# 2                                                  NaN                 NaN
# 3                                                  NaN                 NaN
# 4                                                  NaN                 NaN
# ..                                                 ...                 ...
# 107              تشجع على الفهم العميق والتفكير النقدي              true
# 108                                                NaN                 NaN
# 109                                                NaN                 NaN
# 110                                                NaN                 NaN
# 111                                                NaN                 NaN
#
#                                               option_4 option_4_is_correct  \
# 0    للأسرة ممارسات اتجاه الطفل قد تكون لها تأثير إ...               true
# 1                                                  NaN                 NaN
# 2                                                  NaN                 NaN
# 3                                                  NaN                 NaN
# 4                                                  NaN                 NaN
# ..                                                 ...                 ...
# 107                                                NaN                 NaN
# 108                                                NaN                 NaN
# 109                                                NaN                 NaN
# 110                                                NaN                 NaN
# 111                                                NaN                 NaN
#
#     option_5 option_5_is_correct option_6 option_6_is_correct option_7  \
# 0        NaN                 NaN      NaN                 NaN      NaN
# 1        NaN                 NaN      NaN                 NaN      NaN
# 2        NaN                 NaN      NaN                 NaN      NaN
# 3        NaN                 NaN      NaN                 NaN      NaN
# 4        NaN                 NaN      NaN                 NaN      NaN
# ..       ...                 ...      ...                 ...      ...
# 107      NaN                 NaN      NaN                 NaN      NaN
# 108      NaN                 NaN      NaN                 NaN      NaN
# 109      NaN                 NaN      NaN                 NaN      NaN
# 110      NaN                 NaN      NaN                 NaN      NaN
# 111      NaN                 NaN      NaN                 NaN      NaN
#
#     option_7_is_correct  score
# 0                   NaN      1
# 1                   NaN      1
# 2                   NaN      1
# 3                   NaN      1
# 4                   NaN      1
# ..                  ...    ...
# 107                 NaN      1
# 108                 NaN      1
# 109                 NaN      1
# 110                 NaN      1
# 111                 NaN      1
#
# [112 rows x 17 columns]

# %%
questions.to_excel('../csv/sanketika_questions.xlsx', index=False)

# %%
quiz = quiz[['QUIZ_CODE ', 'Question_code']]
quiz = quiz.rename(columns=
                   {
        "QUIZ_CODE":"code",
        "Question_code":"questions"
    }
).dropna(how='all').fillna(method='ffill')
# Out:
# /var/folders/1y/4098srp972733z2bdwdhtr447rh153/T/ipykernel_17498/690061221.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ).dropna(how='all').fillna(method='ffill')

# %%
x = quiz.to_dict(orient='index')
out = {}

# %%
for i in x:
    if out.get(x[i]['QUIZ_CODE ']) == None:
        out[x[i]['QUIZ_CODE ']]  = [x[i]['questions']]
    else:
        out[x[i]['QUIZ_CODE ']].append(x[i]['questions'])

for i in out:
    out[i] = ','.join(out[i])

# %%
quiz = pd.DataFrame.from_dict(out, orient='index').reset_index()
quiz.columns = ['code', 'questions']
quiz['quiz_name'] = quiz['code']
quiz['max_attempts'] = 3
quiz['language'] = 'Arabic'
quiz['quiz_type'] = 'practice'

quiz.to_excel('../csv/sanketika_quiz.xlsx', index=False)
