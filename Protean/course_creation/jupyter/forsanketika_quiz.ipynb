# %%
# !! pip3 install openpyxl
import pandas as pd

# %%
quiz = pd.read_csv('../csv/q.csv')
content = pd.read_csv('../csv/new_content.csv')
content = content[['content_name', 'content_code']]
content = content[~content['content_code'].str.contains('_V')]
content.rename(columns={'content_name': 'quiz_name', 'content_code': 'code'}, inplace=True)

# %%
quiz = quiz.drop(columns=['COURSE_CODE', 'COURSE_TITLE', 'MODULES_TITLE', 'MODULE_CODE', 'url video']).dropna(how='all')

# %%
quiz = quiz[['Quiz_code', 'Code_Question ', 'Quiz', 'option 1',
       'answer', 'option 2', 'answer.1', 'option 4', 'answer.2', 'option5',
       'answer.3', 'option6', 'answer.4', 'option7', 'answer.5', 'option8',
       'answer.6', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
       'Unnamed: 26', 'Unnamed: 27']]
# .drop(columns=['Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25','Unnamed: 26','Unnamed: 27'])
quiz.dropna(inplace=True,how='all')
quiz = quiz.dropna(subset=['Code_Question '])

# %%
quiz.dropna(subset=['Quiz'], inplace=True)
quiz.shape
# Out:
# (58, 23)

# %%
questions = quiz[['Code_Question ', 'Quiz', 'option 1', 'answer', 'option 2',
       'answer.1', 'option 4', 'answer.2', 'option5', 'answer.3', 'option6',
       'answer.4', 'option7', 'answer.5', 'option8', 'answer.6']]

questions = questions.rename(columns={
    "Code_Question ":"code",
    "Quiz":"question_text",
    "option 1":"option_1",
    "answer":"option_1_is_correct",
    "option 2":"option_2",
    "answer.1":"option_2_is_correct",
    "option 4":"option_3",
    "answer.2":"option_3_is_correct",
    'option5':'option_4',
    'answer.3':'option_4_is_correct',
    'option6':'option_5',
    'answer.4':'option_5_is_correct',
    'option7':'option_6',
    'answer.5':'option_6_is_correct',
    'option8':'option_7',
    'answer.6':'option_7_is_correct'
})
# questions.dropna(inplace=True,how='all')
questions['score'] = 1

# %%
questions = questions.dropna(subset=['question_text'])

# %%
questions.columns
# Out:
# Index(['code', 'question_text', 'option_1', 'option_1_is_correct', 'option_2',
#        'option_2_is_correct', 'option_3', 'option_3_is_correct', 'option_4',
#        'option_4_is_correct', 'option_5', 'option_5_is_correct', 'option_6',
#        'option_6_is_correct', 'option_7', 'option_7_is_correct', 'score'],
#       dtype='object')

# %%
cols = ['option_1_is_correct', 'option_2_is_correct', 'option_3_is_correct', 'option_4_is_correct','option_5_is_correct','option_6_is_correct','option_7_is_correct']
# for col in cols:
#     questions[col] = questions[col].replace({'VRAI': 'true', 'FAUX': 'false'}).str.lower()

# %%
questions.to_csv('../csv/latest_new_sanketika_questions.csv', index=False)
questions.to_excel('../csv/latest_new_sanketika_questions.xlsx', index=False)

# %%
quiz = quiz[['Quiz_code', 'Code_Question ']]
quiz = quiz.rename(columns=
                   {
        "Quiz_code":"code",
        "Code_Question ":"questions"
    }
).dropna(how='all').fillna(method='ffill')
# Out:
# /var/folders/1y/4098srp972733z2bdwdhtr447rh153/T/ipykernel_49208/2261049740.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ).dropna(how='all').fillna(method='ffill')

# %%
quiz
# Out:
#               code            questions
# 0   FMPS_C001_QV01   FMPS_C001_QV01_Q_1
# 1   FMPS_C001_QV01   FMPS_C001_QV01_Q_2
# 2   FMPS_C001_QV01   FMPS_C001_QV01_Q_3
# 3   FMPS_C001_QV01   FMPS_C001_QV01_Q_4
# 4   FMPS_C001_QV01   FMPS_C001_QV01_Q_5
# 5   FMPS_C001_QV02   FMPS_C001_QV02_Q_1
# 6   FMPS_C001_QV02   FMPS_C001_QV02_Q_2
# 7   FMPS_C001_QV02   FMPS_C001_QV02_Q_3
# 8   FMPS_C001_QV02   FMPS_C001_QV02_Q_4
# 9   FMPS_C001_QV02   FMPS_C001_QV02_Q_5
# 10  FMPS_C001_QV03   FMPS_C001_QV03_Q_1
# 11  FMPS_C001_QV03   FMPS_C001_QV03_Q_2
# 12  FMPS_C001_QV03   FMPS_C001_QV03_Q_3
# 13  FMPS_C001_QV03   FMPS_C001_QV03_Q_4
# 14  FMPS_C001_QV03   FMPS_C001_QV03_Q_5
# 15  FMPS_C001_QV04   FMPS_C001_QV04_Q_1
# 16  FMPS_C001_QV04   FMPS_C001_QV04_Q_2
# 17  FMPS_C001_QV04   FMPS_C001_QV04_Q_3
# 18  FMPS_C001_QV04   FMPS_C001_QV04_Q_4
# 19  FMPS_C001_QV04   FMPS_C001_QV04_Q_5
# 20  FMPS_C006_QV06   FMPS_C006_QV06_Q_1
# 21  FMPS_C006_QV06   FMPS_C006_QV06_Q_2
# 22  FMPS_C006_QV06   FMPS_C006_QV06_Q_3
# 23  FMPS_C006_QV06   FMPS_C006_QV06_Q_4
# 24  FMPS_C006_QV06   FMPS_C006_QV06_Q_5
# 25  FMPS_C006_QV06   FMPS_C006_QV06_Q_6
# 26  FMPS_C006_QV06   FMPS_C006_QV06_Q_7
# 27  FMPS_C006_QV06   FMPS_C006_QV06_Q_8
# 28  FMPS_C006_QV06   FMPS_C006_QV06_Q_9
# 29  FMPS_C006_QV06  FMPS_C006_QV06_Q_10
# 30  FMPS_C008_QV02   FMPS_C008_QV02_Q_1
# 31  FMPS_C008_QV02   FMPS_C008_QV02_Q_2
# 32  FMPS_C008_QV02   FMPS_C008_QV02_Q_3
# 33  FMPS_C008_QV02   FMPS_C008_QV02_Q_4
# 34  FMPS_C008_QV02   FMPS_C008_QV02_Q_5
# 35  FMPS_C008_QV02   FMPS_C008_QV02_Q_6
# 36  FMPS_C008_QV05   FMPS_C008_QV05_Q_6
# 37  FMPS_C008_QV05   FMPS_C008_QV05_Q_1
# 38  FMPS_C008_QV05   FMPS_C008_QV05_Q_2
# 39  FMPS_C008_QV05   FMPS_C008_QV05_Q_3
# 40  FMPS_C008_QV05   FMPS_C008_QV05_Q_4
# 41  FMPS_C008_QV08   FMPS_C008_QV08_Q_1
# 42  FMPS_C008_QV08   FMPS_C008_QV08_Q_2
# 43  FMPS_C008_QV08   FMPS_C008_QV08_Q_3
# 44  FMPS_C008_QV08   FMPS_C008_QV08_Q_4
# 45  FMPS_C008_QV08   FMPS_C008_QV08_Q_5
# 46  FMPS_C008_QV08   FMPS_C008_QV08_Q_6
# 47  FMPS_C009_QV04   FMPS_C009_QV04_Q_1
# 48  FMPS_C009_QV04   FMPS_C009_QV04_Q_2
# 49  FMPS_C009_QV04   FMPS_C009_QV04_Q_3
# 50  FMPS_C009_QV04   FMPS_C009_QV04_Q_4
# 51  FMPS_C009_QV04   FMPS_C009_QV04_Q_5
# 52  FMPS_C009_QV04   FMPS_C009_QV04_Q_6
# 53  FMPS_C009_QV04   FMPS_C009_QV04_Q_7
# 54  FMPS_C011_QV02   FMPS_C011_QV02_Q_1
# 55  FMPS_C011_QV02   FMPS_C011_QV02_Q_2
# 56  FMPS_C011_QV02   FMPS_C011_QV02_Q_3
# 57  FMPS_C011_QV02   FMPS_C011_QV02_Q_4

# %%
quiz['code'] = quiz['code'].astype(str)
content['code'] = content['code'].astype(str)

# %%
x = quiz.to_dict(orient='index')
out = {}
count = {}
a = 0

# %%
quiz
# Out:
#               code            questions
# 0   FMPS_C001_QV01   FMPS_C001_QV01_Q_1
# 1   FMPS_C001_QV01   FMPS_C001_QV01_Q_2
# 2   FMPS_C001_QV01   FMPS_C001_QV01_Q_3
# 3   FMPS_C001_QV01   FMPS_C001_QV01_Q_4
# 4   FMPS_C001_QV01   FMPS_C001_QV01_Q_5
# 5   FMPS_C001_QV02   FMPS_C001_QV02_Q_1
# 6   FMPS_C001_QV02   FMPS_C001_QV02_Q_2
# 7   FMPS_C001_QV02   FMPS_C001_QV02_Q_3
# 8   FMPS_C001_QV02   FMPS_C001_QV02_Q_4
# 9   FMPS_C001_QV02   FMPS_C001_QV02_Q_5
# 10  FMPS_C001_QV03   FMPS_C001_QV03_Q_1
# 11  FMPS_C001_QV03   FMPS_C001_QV03_Q_2
# 12  FMPS_C001_QV03   FMPS_C001_QV03_Q_3
# 13  FMPS_C001_QV03   FMPS_C001_QV03_Q_4
# 14  FMPS_C001_QV03   FMPS_C001_QV03_Q_5
# 15  FMPS_C001_QV04   FMPS_C001_QV04_Q_1
# 16  FMPS_C001_QV04   FMPS_C001_QV04_Q_2
# 17  FMPS_C001_QV04   FMPS_C001_QV04_Q_3
# 18  FMPS_C001_QV04   FMPS_C001_QV04_Q_4
# 19  FMPS_C001_QV04   FMPS_C001_QV04_Q_5
# 20  FMPS_C006_QV06   FMPS_C006_QV06_Q_1
# 21  FMPS_C006_QV06   FMPS_C006_QV06_Q_2
# 22  FMPS_C006_QV06   FMPS_C006_QV06_Q_3
# 23  FMPS_C006_QV06   FMPS_C006_QV06_Q_4
# 24  FMPS_C006_QV06   FMPS_C006_QV06_Q_5
# 25  FMPS_C006_QV06   FMPS_C006_QV06_Q_6
# 26  FMPS_C006_QV06   FMPS_C006_QV06_Q_7
# 27  FMPS_C006_QV06   FMPS_C006_QV06_Q_8
# 28  FMPS_C006_QV06   FMPS_C006_QV06_Q_9
# 29  FMPS_C006_QV06  FMPS_C006_QV06_Q_10
# 30  FMPS_C008_QV02   FMPS_C008_QV02_Q_1
# 31  FMPS_C008_QV02   FMPS_C008_QV02_Q_2
# 32  FMPS_C008_QV02   FMPS_C008_QV02_Q_3
# 33  FMPS_C008_QV02   FMPS_C008_QV02_Q_4
# 34  FMPS_C008_QV02   FMPS_C008_QV02_Q_5
# 35  FMPS_C008_QV02   FMPS_C008_QV02_Q_6
# 36  FMPS_C008_QV05   FMPS_C008_QV05_Q_6
# 37  FMPS_C008_QV05   FMPS_C008_QV05_Q_1
# 38  FMPS_C008_QV05   FMPS_C008_QV05_Q_2
# 39  FMPS_C008_QV05   FMPS_C008_QV05_Q_3
# 40  FMPS_C008_QV05   FMPS_C008_QV05_Q_4
# 41  FMPS_C008_QV08   FMPS_C008_QV08_Q_1
# 42  FMPS_C008_QV08   FMPS_C008_QV08_Q_2
# 43  FMPS_C008_QV08   FMPS_C008_QV08_Q_3
# 44  FMPS_C008_QV08   FMPS_C008_QV08_Q_4
# 45  FMPS_C008_QV08   FMPS_C008_QV08_Q_5
# 46  FMPS_C008_QV08   FMPS_C008_QV08_Q_6
# 47  FMPS_C009_QV04   FMPS_C009_QV04_Q_1
# 48  FMPS_C009_QV04   FMPS_C009_QV04_Q_2
# 49  FMPS_C009_QV04   FMPS_C009_QV04_Q_3
# 50  FMPS_C009_QV04   FMPS_C009_QV04_Q_4
# 51  FMPS_C009_QV04   FMPS_C009_QV04_Q_5
# 52  FMPS_C009_QV04   FMPS_C009_QV04_Q_6
# 53  FMPS_C009_QV04   FMPS_C009_QV04_Q_7
# 54  FMPS_C011_QV02   FMPS_C011_QV02_Q_1
# 55  FMPS_C011_QV02   FMPS_C011_QV02_Q_2
# 56  FMPS_C011_QV02   FMPS_C011_QV02_Q_3
# 57  FMPS_C011_QV02   FMPS_C011_QV02_Q_4

# %%
for i in x:
    a+=1
    if out.get(x[i]['code']) == None:
        out[x[i]['code']]  = [x[i]['questions']]
        count[x[i]['code']] = 1
    else:
        out[x[i]['code']].append(x[i]['questions'])
        count[x[i]['code']] += 1

for i in out:
    out[i] = ','.join(out[i])

# %%
quiz = pd.DataFrame.from_dict(out, orient='index').reset_index()
quiz.columns = ['code', 'questions']
quiz = quiz.merge(content, on='code', how='left')
quiz['max_attempts'] = 2
quiz['language'] = 'Arabic'
quiz['quiz_type'] = 'practice'

# %%
quiz['quiz_name'] = quiz.apply(lambda row: row['code'] if pd.isna(row['quiz_name']) else row['quiz_name'], axis=1)

# %%
quiz.drop_duplicates(subset=['code'], inplace=True)
quiz.to_csv('../csv/latest_new_sanketika_quiz.csv', index=False)
quiz.to_excel('../csv/latest_new_sanketika_quiz.xlsx', index=False)
